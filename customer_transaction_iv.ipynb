# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pyspark.sql import SparkSession,DataFrame
from pyspark.sql.functions import udf,col,split,explode_outer,regexp_replace,from_json,date_format,to_timestamp,expr,from_utc_timestamp,lit
from pyspark.sql.types import DoubleType,StructType, StructField, ArrayType, StringType, TimestampType
import pytz
from cryptography.fernet import Fernet

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import matplotlib.pyplot as plt
import os

# %%
def flatten_json(df):

    """
    Flattens a DataFrame with complex nested fields (Arrays and Structs) by converting them into individual columns.
   
    Parameters:
    - df: The input DataFrame with complex nested fields
   
    Returns:
    - The flattened DataFrame with all complex fields expanded into separate columns.
   """
   # compute Complex Fields (Lists and Structs) in Schema   
    complex_fields = dict([(field.name, field.dataType,)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
    print(df.schema)
    print("")
    while len(complex_fields)!=0:
      col_name=list(complex_fields.keys())[0]
      print ("Processing :"+col_name+" Type : "+str(type(complex_fields[col_name])))

      # if (type(complex_fields[col_name]) == StringType):
          # print(col_name)
          # print(df.withColumn("new_col",startswith(col_name[0],'{')))
          # print("true")
      # if StructType then convert all sub element to columns.
      # i.e. flatten structs
      if (type(complex_fields[col_name]) == StructType) :
         expanded = [col(col_name+'.'+k).alias(col_name+'_'+k) for k in [ n.name for n in  complex_fields[col_name]]]
         df=df.select("*", *expanded).drop(col_name)
    
      # if ArrayType then add the Array Elements as Rows using the explode function
      # i.e. explode Arrays
      elif (type(complex_fields[col_name]) == ArrayType):    
         df=df.withColumn(col_name,explode_outer(col_name))
    
      # recompute remaining Complex Fields in Schema       
      complex_fields = dict([(field.name, field.dataType)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
    return df

# %%
# Create SparkSession 
spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()

# %%
# localTime = pytz.timezone("Malaysia/Kuala_Lumpur") 
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        #bronze_df to load to datalake/data storage. Bronze layer usually is one to one with source
        bronze_df = spark.read.format("json").load(os.path.join(dirname, filename))
        bronze_row = bronze_df.count()
        print(f"Bronze DataFrame Rows count : {bronze_row}")
        # bronze_df.write.format("delta").mode("append").save(os.path.join(dirname, "cc_sample_transaction1.json"))
# Out:
# /kaggle/input/cc-sample-data/cc_sample_transaction.json
# Bronze DataFrame Rows count : 1296675

# %% [markdown]
# Identify dirty data can be done by execu distinct attributes to find the pattern of the values that can be excluded to make the data clean and valuable. For example for name, we should not expect any symbol or number. You can also use data profiling tools to get the summary of your data to check of consistency and correctness.
# For attributes that must not be nullable, if null exist it will make the data become invalid, we can remove it in transformation layer. Similarly with duplicates data, can be removed/excluded in transformation layer.

# %%
        # Initially can execute bronze_df.printSchema() to get the schema to predefined the attributes.
        #Defines the schemas of the attributes
        personal_detail_schemas = StructType([StructField("person_name", StringType(), True),
                    StructField("gender", StringType(), True),
                    StructField("address", StringType(), True),          
                    StructField("lat", StringType(), True),
                    StructField("long", StringType(), True),
                    StructField("city_pop", StringType(), True),
                    StructField("job", StringType(), True),
                    StructField("dob", StringType(), True)],
                    )
        address_schemas =  StructType([StructField("street", StringType(), True),
                                                        StructField("city", StringType(), True),
                                                        StructField("state", StringType(), True),
                                                        StructField("zip", StringType(), True)])
        #Transformed the data into the preferable data type and format
        bronze_df=bronze_df.withColumn("merch_eff_time",bronze_df.merch_eff_time.cast(DoubleType()))\
        .withColumn("merch_last_update_time",bronze_df.merch_last_update_time.cast(DoubleType()))\
        .withColumn("personal_detail", from_json(col("personal_detail"), personal_detail_schemas))
        bronze_df=bronze_df.withColumn("merch_eff_time",date_format(to_timestamp(bronze_df["merch_eff_time"]/1000000) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))\
        .withColumn("merch_last_update_time",date_format(to_timestamp(bronze_df["merch_last_update_time"]/1000) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))\
        .withColumn("address", from_json(col("personal_detail.address"), address_schemas))\
        .withColumn("trans_date_trans_time",date_format(to_timestamp(bronze_df["trans_date_trans_time"]) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))
        # df.select(col("merch_last_update_time"),col("merch_eff_time"),col("trans_date_trans_time")).show(n=30,truncate=False)
        flatten_df = flatten_json(bronze_df)
        # flatten_df.select(col("personal_detail_person_name"),col("merch_last_update_time"),col("merch_eff_time"),col("trans_date_trans_time")).show(n=100,truncate=False)
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], ", !",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "!",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"],", ,",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"],", ",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], ",eeeee",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], " NOOOO",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "@",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "/",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "\|",","))
        # flatten_df.select(col("personal_detail_person_name")).show(n=100,truncate=False)
        flatten_df = flatten_df.withColumn("personal_detail_person_name", split(flatten_df["personal_detail_person_name"], ',\s*'))
        flatten_df = flatten_df.withColumn("first", flatten_df["personal_detail_person_name"][0])\
        .withColumn("last", flatten_df["personal_detail_person_name"][1])
        # flatten_df.select(col("first"),col("last")).show(n=100,truncate=False)
        flatten_df = flatten_df.drop("personal_detail_address")\
        .drop("personal_detail_person_name")
        flatten_df = flatten_df.withColumnsRenamed({
        "personal_detail_gender": "gender",
        "personal_detail_lat": "lat",
        "personal_detail_long": "long",
        "personal_detail_city_pop": "city_pop",
        "personal_detail_job": "job",
        "personal_detail_dob": "dob",
        "address_street": "street",
        "address_city": "city",
        "address_state": "state",
        "address_zip": "zip"
        })
# Out:
# StructType([StructField('Unnamed: 0', StringType(), True), StructField('amt', StringType(), True), StructField('category', StringType(), True), StructField('cc_bic', StringType(), True), StructField('cc_num', StringType(), True), StructField('is_fraud', StringType(), True), StructField('merch_eff_time', StringType(), True), StructField('merch_last_update_time', StringType(), True), StructField('merch_lat', StringType(), True), StructField('merch_long', StringType(), True), StructField('merch_zipcode', StringType(), True), StructField('merchant', StringType(), True), StructField('personal_detail', StructType([StructField('person_name', StringType(), True), StructField('gender', StringType(), True), StructField('address', StringType(), True), StructField('lat', StringType(), True), StructField('long', StringType(), True), StructField('city_pop', StringType(), True), StructField('job', StringType(), True), StructField('dob', StringType(), True)]), True), StructField('trans_date_trans_time', StringType(), True), StructField('trans_num', StringType(), True), StructField('address', StructType([StructField('street', StringType(), True), StructField('city', StringType(), True), StructField('state', StringType(), True), StructField('zip', StringType(), True)]), True)])
#
# Processing :personal_detail Type : <class 'pyspark.sql.types.StructType'>
# Processing :address Type : <class 'pyspark.sql.types.StructType'>

# %% [markdown]
# For Handling PII data, We can encrypt it using fernet library in the transformation/silver layer. For bronze layer, we can manage it by adding a role based access control (rbac) to restrict only certain user can access it. Potentially only system can access. Each individual are restricted in to access the PII only upon request and the request has been justified and approved by managers.

# %%
        # encrypt func
        def encrypt_data(plain_text, KEY):
            f = Fernet(KEY)
            encrip_text = f.encrypt(str(plain_text).encode()).decode()
            return encrip_text
        encrypt_udf = udf(encrypt_data, StringType())
        # generate the encryption key
        Key = Fernet.generate_key()
        enc_df = flatten_df.withColumn("cc_num", encrypt_udf(col('cc_num'), lit(Key))) 
        #silver_df layer is after the data being transformed and cleaned
        silver_df = enc_df.dropDuplicates()
        silver_row = silver_df.count()
        print(f"Silver DataFrame Rows count : {silver_row}")
        silver_df.show()
# Out:
# Silver DataFrame Rows count : 1296675
# +----------+------+--------------+-----------+--------------------+--------+--------------------+----------------------+------------------+------------------+-------------+--------------------+---------------------+--------------------+------+------------------+---------+--------+--------------------+----------+--------------------+--------------------+-----+-----+-----------+----------+
# |Unnamed: 0|   amt|      category|     cc_bic|              cc_num|is_fraud|      merch_eff_time|merch_last_update_time|         merch_lat|        merch_long|merch_zipcode|            merchant|trans_date_trans_time|           trans_num|gender|               lat|     long|city_pop|                 job|       dob|              street|                city|state|  zip|      first|      last|
# +----------+------+--------------+-----------+--------------------+--------+--------------------+----------------------+------------------+------------------+-------------+--------------------+---------------------+--------------------+------+------------------+---------+--------+--------------------+----------+--------------------+--------------------+-----+-----+-----------+----------+
# |        33| 25.58|      misc_pos|DEUTUS33TRF|gAAAAABoP8BqhBPCH...|       0|2012-23-01 08:23:...|  2012-23-01 08:23:...|         29.737426|        -90.853194|        70395|fraud_Balistreri-...| 2019-23-01 08:23:...|1654da2abfb9e79a5...|     F|           30.4066| -91.1468|  378909| Designer, furniture|1977-02-22|50872 Alex Plain ...|         Baton Rouge|   LA|70808|      Jenna|    Brooks|
# |       194|117.29|   grocery_pos|   APBCUS61|gAAAAABoP8Bqt1vRp...|       0|2012-23-01 10:23:...|  1974-14-15 08:14:...|         32.035674|        -89.835532|        39114|  fraud_Rau and Sons| 2019-23-01 10:23:...|1f24070c1ab4fcdab...|     M|           31.6453| -90.1801|    1196| Librarian, academic|1958-06-11|26975 Richardson ...|              Sontag|   MS|39665|      James|     Reese|
# |       290| 68.96|   grocery_pos|   AIABUS31|gAAAAABoP8BqHm2_u...|       0|2012-49-01 11:49:...|  1974-22-15 08:22:...|         41.182138|        -98.751918|        68817|   fraud_Kilback LLC| 2019-49-01 11:49:...|b2820a9708d41515e...|     F| 41.36600000000001| -98.0054|    1749|    Surveyor, mining|1973-05-07|5053 Bell Crescen...|           Fullerton|   NE|68638|     Cheryl|    Melton|
# |       674|  4.62|  shopping_pos|   APBCUS61|gAAAAABoP8BqmtFI0...|       0|2012-48-01 16:48:...|  2012-48-01 16:48:...|         44.908601|        -85.841895|        49621|fraud_Douglas, Sc...| 2019-48-01 16:48:...|53ebe4ce3dc71fdcc...|     M|           44.5232| -86.2061|     680| Designer, jewellery|1966-12-21|     212 Mary Stream|             Arcadia|   MI|49613|      Jerry|  Robinson|
# |       929|101.15|   food_dining|DEUTUS33TRF|gAAAAABoP8BqJMviS...|       0|2012-46-01 19:46:...|  2012-46-01 19:46:...|         31.549076|        -98.988616|        76827|    fraud_Runte-Mohr| 2019-46-01 19:46:...|13cee3d17da3828ca...|     F|           31.8287|  -99.427|    5908|      Radio producer|1962-04-05|0537 Margaret Com...|             Coleman|   TX|76834|      Robin|     Smith|
# |       998| 41.23|  shopping_net|   APBCUS61|gAAAAABoP8BqtwyxW...|       0|2012-39-01 20:39:...|  2012-39-01 20:39:...|         36.890125|        -80.382986|        24091|    fraud_Mohr-Bayer| 2019-39-01 20:39:...|368a6a87fcbe04ab4...|     F|           37.7827| -80.3129|    5216|Community develop...|1993-10-05|825 Martinez Spri...|White Sulphur Spr...|   WV|24986|    Felicia|     Combs|
# |      2202|  7.34| personal_care|   AIABUS31|gAAAAABoP8BqLDlvK...|       0|1974-12-15 10:12:...|  2012-09-02 06:09:...|         39.392672|        -74.781161|        08317|   fraud_Reichel LLC| 2019-09-02 06:09:...|9819924265e5d21b3...|     F|           39.8016| -75.3478|     504|Engineer, control...|1980-08-17|44197 Jeffrey Por...|          Bridgeport|   NJ| 8014|       Lisa|   Collins|
# |      2452| 13.38|      misc_pos|DEUTUS33TRF|gAAAAABoP8BqcxSfr...|       0|1974-30-15 10:30:...|  2012-09-02 09:09:...|         47.996962|       -121.780825|        98252|    fraud_Herman Inc| 2019-09-02 09:09:...|f202fcd64fe845279...|     F|           47.4974|-122.0107|   50489|           Osteopath|1984-02-29|  000 Jennifer Mills|            Issaquah|   WA|98027|    Crystal|    Fuller|
# |      2534|186.49| entertainment|   ACEEUS31|gAAAAABoP8BqDcJzJ...|       0|2012-17-02 11:17:...|  2012-17-02 11:17:...|           31.3524|        -91.070984|        39633|    fraud_Grimes LLC| 2019-17-02 11:17:...|4484b147601241209...|     M|           30.5668|  -90.482|    8512|Accountant, chart...|1951-09-03|    950 Dunn Squares|             Tickfaw|   LA|70466|Christopher|     Gomez|
# |      2571| 19.04|   grocery_net|   AIABUS31|gAAAAABoP8BqMmFBT...|       0|2012-21-02 12:21:...|  1974-50-15 10:50:...|         39.295093|        -90.316113|        62016|fraud_Ferry, Reic...| 2019-21-02 12:21:...|721ff5ebc91c9f844...|     F|           38.9318| -89.9618|    2401|   Buyer, industrial|1972-01-03|2193 Osborne Run ...|                Moro|   IL|62067|      Susan| Hernandez|
# |      2743| 71.05|   grocery_net|   ACEEUS31|gAAAAABoP8BqeRJVK...|       0|2012-15-02 17:15:...|  2012-15-02 17:15:...|         44.477833|       -123.051087|        97377|    fraud_Dach-Borer| 2019-15-02 17:15:...|20b828a71f56cc3df...|     M|           45.3099|-122.9685|   28278|Research scientis...|1977-07-17|1049 John Ports S...|             Newberg|   OR|97132|    Timothy|   Simmons|
# |      2878| 18.01|health_fitness|   AIABUS31|gAAAAABoP8BqeM5co...|       0|2012-34-02 20:34:...|  2012-34-02 20:34:...|41.699546000000005|        -86.463957|        46552|    fraud_Feil-Morar| 2019-34-02 20:34:...|05c0f4c480f1cb4ff...|     F|           41.4802| -86.6919|    1423|Psychologist, for...|1998-10-07|6114 Adams Harbor...|   Kingsford Heights|   IN|46346|     Carrie|Washington|
# |      2986|133.85|     kids_pets|           |gAAAAABoP8BqTpOa1...|       0|2012-25-02 22:25:...|  2012-25-02 22:25:...|34.848884999999996|       -118.828423|        93243|fraud_Pacocha-Wei...| 2019-25-02 22:25:...|e8882f4a8e8ffcaf7...|     M|           34.5715|-118.0231|  171170|   Chemical engineer|1963-06-04|0638 Fred Ramp Su...|            Palmdale|   CA|93552|      David|   Nichols|
# |      3137|   1.7|  shopping_net|           |gAAAAABoP8Bqzj1O2...|       0|2012-11-03 01:11:...|  2012-11-03 01:11:...|         33.736512|-84.56089200000001|        30336|   fraud_Goyette Inc| 2019-11-03 01:11:...|2ceee454d14107fe0...|     F|           33.1194| -83.8235|    3343|     Theatre manager|1990-06-08|  5619 Mendoza Inlet|            Juliette|   GA|31046|    Rebecca|    Obrien|
# |      3833| 51.18| gas_transport|CITIUS33CHI|gAAAAABoP8BqrzRgJ...|       0|2012-51-03 15:51:...|  2012-51-03 15:51:...|         37.274145|        -77.751814|        23838|    fraud_Sporer Inc| 2019-51-03 15:51:...|af51bd5dff9bc6ffc...|     F|           36.9688| -78.5615|    1970|     Energy engineer|1985-09-02|3861 Anderson Ram...|       Drakes Branch|   VA|23937|    Valerie|     Davis|
# |      3925|144.68|  shopping_pos|   AIABUS31|gAAAAABoP8BqLHv6q...|       0|2012-55-03 17:55:...|  2012-55-03 17:55:...|         43.218927|        -72.687308|        05148|fraud_Jast-McDermott| 2019-55-03 17:55:...|95e02ee04ae8a14ab...|     M|43.196000000000005| -72.3001|     477|     Naval architect|1988-04-15|8415 Vaughn Squar...|             Acworth|   NH| 3601|      Jesse|   Roberts|
# |      3960| 179.4|   grocery_pos|       Null|gAAAAABoP8BqWTxyY...|       0|2012-55-03 18:55:...|  2012-55-03 18:55:...|         40.008184|        -77.614738|        17244|fraud_Goldner, Ko...| 2019-55-03 18:55:...|976b3708622c414f1...|     F|           41.0036| -78.1104|     489|Pension scheme ma...|1956-09-15|897 Daugherty Mis...|           Grassflat|   PA|16839|  Elizabeth|     Payne|
# |      3975| 45.92|   grocery_net|           |gAAAAABoP8BqUfSXy...|       0|2012-18-03 19:18:...|  2012-18-03 19:18:...|         42.855156|        -72.640564|        05301|fraud_Skiles-Anku...| 2019-18-03 19:18:...|15e6476f146ce4feb...|     M|           42.2848| -71.7205|   35299|English as a seco...|1975-04-30|   37910 Ward Lights|          Shrewsbury|   MA| 1545|      Frank|    Foster|
# |      4008| 24.89| personal_care|   ADMDUS41|gAAAAABoP8BqTc4tX...|       0|2012-05-03 20:05:...|  1974-00-15 14:00:...|         35.501792|         -80.44584|        28138| fraud_Dickinson Ltd| 2019-05-03 20:05:...|8ec10ce2b51cd06fc...|     F|           36.2017| -81.1286|   21134| Dispensing optician|1984-03-06|25961 Beverly Uni...|    North Wilkesboro|   NC|28659|      Sarah|     Clark|
# |      4260|  7.44|   food_dining|   ACEEUS31|gAAAAABoP8BqXKtDB...|       0|2012-46-03 23:46:...|  2012-46-03 23:46:...|37.073271000000005|        -96.973873|        67005|fraud_Stiedemann Ltd| 2019-46-03 23:46:...|82076957c09414a94...|     F|           38.0261| -97.6666|    1689|              Gaffer|1997-11-18|00315 Ashley Valleys|             Burrton|   KS|67020|       Mary|  Williams|
# +----------+------+--------------+-----------+--------------------+--------+--------------------+----------------------+------------------+------------------+-------------+--------------------+---------------------+--------------------+------+------------------+---------+--------+--------------------+----------+--------------------+--------------------+-----+-----+-----------+----------+
# only showing top 20 rows

# %% [markdown]
# to identify the potential customer based on the number of registered credit card in each state

# %%
        table = spark.sql('''
        select state, count(distinct cc_num) as num_of_cc
        from {tb}
        group by state order by 2 desc limit 5
        ''', tb=silver_df)
        table.show(n=500,truncate=False)
# Out:
# +-----+---------+
# |state|num_of_cc|
# +-----+---------+
# |TX   |94876    |
# |NY   |83501    |
# |PA   |79847    |
# |CA   |56360    |
# |OH   |46480    |
# +-----+---------+

# %%
        data = table.toPandas()
        plt.bar(data.state,data.num_of_cc)
        plt.title("Registered Customer")

        # Setting the X and Y labels

        plt.xlabel('state')

        plt.ylabel('num_of_cc')

        # Adding the legends

        plt.show()

# %% [markdown]
# to identify customer credit card use for potential fraud or suspicious use

# %%
        #to identify credit card use for fraud
        table2 = spark.sql('''
        select *
        from {tb}
        where is_fraud = '1'
        ''', tb=silver_df)
        table2.show(n=5,truncate=False)
# Out:
# +----------+-------+------------+-----------+------------------------------------------------------------------------------------------------------------------------+--------+------------------------------+------------------------------+---------+----------+-------------+---------------------------------+------------------------------+--------------------------------+------+------------------+--------+--------+----------------------------------+----------+-----------------------------+-------------+-----+-----+-------+-------+
# |Unnamed: 0|amt    |category    |cc_bic     |cc_num                                                                                                                  |is_fraud|merch_eff_time                |merch_last_update_time        |merch_lat|merch_long|merch_zipcode|merchant                         |trans_date_trans_time         |trans_num                       |gender|lat               |long    |city_pop|job                               |dob       |street                       |city         |state|zip  |first  |last   |
# +----------+-------+------------+-----------+------------------------------------------------------------------------------------------------------------------------+--------+------------------------------+------------------------------+---------+----------+-------------+---------------------------------+------------------------------+--------------------------------+------+------------------+--------+--------+----------------------------------+----------+-----------------------------+-------------+-----+-----+-------+-------+
# |19426     |1081.35|shopping_net|AIABUS31   |gAAAAABoP8Gnn2ulb9SFkMM1bQ725ItDYy7MjaLWLsVXvEINmkFi6UxsZ0Hh1E0rdupjXktqWAOw_EV7slAJiagiEFbJlMqelQ==                    |1       |2012-53-13 03:53:59.7271 +0000|2012-53-13 03:53:59.1260 +0000|42.455406|-79.52164 |14769        |fraud_Boyer-Reichert             |2019-53-13 03:53:59.0000 +0000|8545f40c91a37f8015749b0f962cff20|M     |41.5205           |-80.0573|5507    |Retail merchandiser               |1973-07-28|911 Sabrina Trafficway       |Cochranton   |PA   |16314|Larry  |House  |
# |47908     |726.63 |misc_pos    |ACEEUS31   |gAAAAABoP8GnDltqRoE3Iw7N_LsdXB8m959xqa5va_XVV46qvzKBiaD8Em0DyzflL3r1oXw7QuV6QFwXiHXHtRFozVyrxoyZiUaICZEzszTe32A-cAsIN94=|1       |2012-31-29 08:31:00.5873 +0000|2012-31-29 08:31:00.3280 +0000|35.311304|-99.108549|73641        |fraud_Dickinson-Rempel           |2019-31-29 08:31:00.0000 +0000|347b8b8d2898fc0e3a3a4dee5026a397|F     |34.7032           |-98.9591|540     |Research scientist (life sciences)|1983-10-12|174 Jennifer Meadow Apt. 467 |Mountain Park|OK   |73559|Renee  |Parrish|
# |95943     |307.7  |grocery_pos |DEUTUS33TRF|gAAAAABoP8Gn0to7FR105ZfXabZSaZyEHYxo9w4pao247IZImUWG4_oejyjF2lJB1eOnGpGX52LqoWz0iofetEsyhMFBPSElow==                    |1       |2012-32-26 09:32:51.4883 +0000|1974-33-20 22:33:17.1840 +0000|39.201694|-96.933869|67487        |fraud_Schultz, Simonis and Little|2019-32-26 09:32:51.0000 +0000|5e77445bdeb5bd5f6b3e913ca1f17549|F     |40.0456           |-97.4735|121     |Set designer                      |1996-04-04|5205 Annette Islands Apt. 043|Hubbell      |NE   |68375|Chelsea|Silva  |
# |101946    |758.33 |shopping_net|APBCUS61   |gAAAAABoP8GnIyawDlbh8dFamZAfhJIFiAr5KpTcYXe8DO9TXFhoO_ZC3U6SPTQ59sNn6c5LVl0UGV-mpT79vX_wurmEvNBGjQ==                    |1       |2012-44-01 03:44:50.5463 +0000|2012-44-01 03:44:50.7420 +0000|37.605358|-80.7503  |24981        |fraud_Reichert, Rowe and Mraz    |2019-44-01 03:44:50.0000 +0000|88ccbaee6fe87034bfc47505b17d6d19|M     |38.388000000000005|-79.9906|365     |Special effects artist            |1970-03-14|411 Laurie Fords             |Cass         |WV   |24927|Bryan  |Miller |
# |21691     |714.88 |misc_net    |NA         |gAAAAABoP8Gn_voPBDkBRtBdamrG994wknDmI_ycCQvRHw5VMSmO529I3a1tsJkY4uzzsZCDYPNmWw6xOzfI3vnV5loUHFhJgA==                    |1       |2012-56-14 07:56:26.3361 +0000|2012-56-14 07:56:26.8060 +0000|42.686461|-75.038985|13348        |fraud_Brown PLC                  |2019-56-14 07:56:26.0000 +0000|67d7968c6b5916bc05daf8ee2186ccd7|M     |42.4069           |-74.1528|277     |Glass blower/designer             |1971-12-12|583 Gray Creek               |Oak Hill     |NY   |12460|Andrew |Tucker |
# +----------+-------+------------+-----------+------------------------------------------------------------------------------------------------------------------------+--------+------------------------------+------------------------------+---------+----------+-------------+---------------------------------+------------------------------+--------------------------------+------+------------------+--------+--------+----------------------------------+----------+-----------------------------+-------------+-----+-----+-------+-------+
# only showing top 5 rows

# %% [markdown]
# number of credit cards that are potentialy fraudulent or suspicious in each state.

# %%
        table3 = spark.sql('''
        select state, count(distinct cc_num) as num_of_cc
        from {tb}
        where is_fraud = '1'
        group by state order by 2 desc limit 5
        ''', tb=silver_df)
        table3.show(n=500,truncate=False)
# Out:
# +-----+---------+
# |state|num_of_cc|
# +-----+---------+
# |NY   |555      |
# |TX   |479      |
# |PA   |458      |
# |CA   |326      |
# |OH   |321      |
# +-----+---------+

# %%
        data3 = table3.toPandas()
        plt.bar(data3.state,data3.num_of_cc)
        plt.title("Quantity of Fraud CC")

        # Setting the X and Y labels

        plt.xlabel('state')

        plt.ylabel('num_of_cc')

        # Adding the legends

        plt.show()

# %% [markdown]
# Identify which segment customer usage of credit card to offer better credit card plan / type for better customer satisfaction

# %%
        table4 = spark.sql('''
        with cust_transaction as (select cc_num, first, last, category, count(*) as category_count, sum(amt) as total_amount
        from {tb}
        where is_fraud = '0'
        group by 1,2,3,4
        )
        select cc_num, first, last category,category_count, total_amount from (
        select *, rank() over (partition by cc_num order by total_amount desc) rnk from cust_transaction)
        where rnk <=5
        order by cc_num, total_amount desc
 
        ''', tb=silver_df)
        table4.show(n=100,truncate=False)
# Out:
# +------------------------------------------------------------------------------------------------------------------------+-----------+----------+--------------+------------+
# |cc_num                                                                                                                  |first      |category  |category_count|total_amount|
# +------------------------------------------------------------------------------------------------------------------------+-----------+----------+--------------+------------+
# |gAAAAABoP8K----SKKlpuqWOmpTou8pVlxKHEWWu0_J8kOkDEyoXhfT7IFQP_FV7p0HrKDYoK6E14DOBikoHyWWPvflHrD8lN3rpfcJsvuWBefQb7S6uksU=|Timothy    |Kirby     |1             |36.26       |
# |gAAAAABoP8K---75MT_EZa6FpA8kEp8rMjvgReVj3Whqf5Goer5nqGt0n1zeh5lUF3rIWg1beJAVVg-TiU2mWXc00I3JQr7miQ==                    |Kristen    |Hanson    |1             |8.87        |
# |gAAAAABoP8K---Ne13McxeL9Q603KnON0ruM5Qbp4rudCouFbfVPh4FgCtYqrNIX-EOgCTE1byW-U8ZHHct9PUUxCyGJO_wXYbvvkPQx3Ca7pwcvC7t6Rdo=|Regina     |Johnston  |1             |65.02       |
# |gAAAAABoP8K---ugrXXIczmaooBU5d1ygQHeYavworVfB3cyKoB5B-8ahTWtjMhP6cRmn6MUExWOYsQWZcDHxZ8s1iqFsP6AqXs2UMpGXhLrvGM0LA8dl30=|William    |Marshall  |1             |86.55       |
# |gAAAAABoP8K---vWTylgIh0jn74RrSY0xph4KcUcaVRVQWNJbkmCelOs1abfXBLJ0mopLhwS_JoyOYgZED02KV2cCQxPEX-IjA==                    |Zachary    |Boone     |1             |72.09       |
# |gAAAAABoP8K--0iNyKHWvNJOFZOiL2cgS1T45GJyp3fpVVYS_EGe5IzFT79T9zKwku26AzN3g0yntAONFt7lAQDebpbm-jemDw==                    |John       |Chandler  |1             |3.6         |
# |gAAAAABoP8K--0j-IOVzgrcWsErvT4H023MwHi7fFZVONKUC9ir6r6fCkBJIFO-6TyWzmCLB0Gi8_j4eZcAo6WcCggmmoJZdwuXt5KuFRVzKxkvW-kbu0TM=|Douglas    |Smith     |1             |44.47       |
# |gAAAAABoP8K--0loWWV22-ZB6pl7Hy6qB44rB6T3BgTZeyoFD5178Tj9AqHB0gbkGQGv_-thGAYan-81yFhQHmL_l3hdQuouDEczs9WvowghFnLYHT4atK4=|Tami       |Forbes    |1             |39.96       |
# |gAAAAABoP8K--0vSeVDTzoAbPsYegr39lmu0_qJk_dnsE06D8JnChwtJtGlDfMawfT48-rx5fAlctW16BYbSbtXGl7BrTmkbgnCQIucXt0qBxFGcrsAcqOQ=|David      |Rodriguez |1             |7.05        |
# |gAAAAABoP8K--10uyJnUfaoWUTfAShIN5F0BXRfKd9r0veHvRAtZdTu-GjPpJnHVfwszLiyTS_D2MnI0mBqD4sYLLlMsNmIFrLfTxGMrqybt5um7wHi-Uhw=|Margaret   |Gibson    |1             |7.44        |
# |gAAAAABoP8K--1NF3hHHTG5jdrr3PjmO971PLHxd35-OLcQNJpkQelJfOKpskqqmoLZoDq_1BiUViTldLkWePwRxOhZtDVbX_VIQNuvfPJMtScCFRtHBFEE=|Christopher|Gregory   |1             |26.62       |
# |gAAAAABoP8K--1goYiuyNWRwx79wkPJQp8ZRks4v9CceOfRDfiq3RwreJ4JIIUJyBYUyOOPO8-kFPRcc6si8THOkWrsEff8yAw==                    |Lori       |Mclean    |1             |7.02        |
# |gAAAAABoP8K--1hJP8WflM5g1Lt60kTSlAN_MPs1YQbLi6_hFvFnOPpTA_DmNsjQH48T0yAXuSCuOPWQnwVTiA1_FDggm5nI46jTHsJkyOEFTE_9L8wl7Ho=|Toni       |Gomez     |1             |14.53       |
# |gAAAAABoP8K--1kqvS-UjVk5uQVYDhHcaXBUOcBf7HObatMOEsVHvraKQhJAh9x6TyiGbL925I8Xaiaut3337wA8X-SfpodAOw==                    |David      |Kirby     |1             |196.52      |
# |gAAAAABoP8K--2VJ0r24kEadmtZqhMpnKrS5JUnH_7ixDvvEsYrm4pe2t4fO8zBvnn5g0Qfb4acMjxGG5s-3XovbRDGZ_nvyqBlh0YCFyqxGTznI8qrd4WQ=|Robert     |Goodman   |1             |86.18       |
# |gAAAAABoP8K--2YJRcyYftN9a1NV2VKnOkh6uWlBtoorAADCA0t8g3A9Lao_lUwoaA83MDyC3fcH-CDETq5dpZ249d-TUzZ0k5dtxZVnAmS1iMpNU_2T1X8=|Allen      |Bell      |1             |74.38       |
# |gAAAAABoP8K--2k3pCkwtvkFgYuR3v0lrujNntf4TDZ30mYVWQYsYaPv69e1rCpu5uaovluOs3LslLB9JeHD6AW4jLIUC-w3Wg==                    |Michael    |Gross     |1             |47.9        |
# |gAAAAABoP8K--3kB0Ow4NvPr9w0VVZVxkiepE8llunP6DujCH6OCqNpf57EuotzeYb4oConEL17C8fdh8Yp8J7cCd5x32YYJ8w==                    |Mary       |Mcintyre  |1             |13.47       |
# |gAAAAABoP8K--3uoSOj0T6GoqgRW26XaGjVQgTjnh1itkZebpUQnU1izu-mj5rqKHj2ASRzIdu14xLIeaKpRvWTXW4P7IKY7KQokXFnKvNlMlMCC_QJQpuE=|Steven     |Sanders   |1             |8.44        |
# |gAAAAABoP8K--42BcNPYYEekNWQ6RLv75M3xSgQB7X27NSxm21MWwPOo6KC1Xo7Iaws3yeGjLniJCgQJY-fMfO4_-M0R1m_2Tt4iBgXUJxwymaae3_NYzxY=|Kathleen   |Heath     |1             |129.65      |
# |gAAAAABoP8K--4Nu6--8Xn2S-5sabXUm5xF_tJ3kA6w9brkdK8eTppJyS5bZa_0j_nKuDfag0mOZeOjecv5udoovILOxdJy5OQotxku5za7kgGJuicWJHIw=|Charles    |Moreno    |1             |85.94       |
# |gAAAAABoP8K--4Te4X6C_QW94QjywMdoJrv9819wDIpcfuoQjHKeRAEld9kjcu85ixZbwidIjYzLZEnOMR-jnM3Hq2n-rUpANiMNDeCOUaZwIS_KBjyLxNY=|Kyle       |Simmons   |1             |61.37       |
# |gAAAAABoP8K--4sKFUmLHh1Z8rRIEYsjM7NuMWy8iZvkoBpzTKN2VyNOS1QSntHBOS5THUni5S3jCQZANzLvF1CdpdOaaaGsHUvfdjNrjyu9HAA_bQbZWWE=|Aaron      |Pena      |1             |53.36       |
# |gAAAAABoP8K--4xYGQ6RpILFXhL6D8qofFMM50nhKIk_am6oFsaoWxaHA9SPIfZ5Q23flT6-aOy7n4RFZ9uNLT-XbtRHbRrIZw==                    |Kenneth    |Doyle     |1             |2.84        |
# |gAAAAABoP8K--59vmb0cR8JQbIXVvTEQG5_96r0N6pk_ODYHf7xW7TaX-f7zGBI8so6lxAr1gfhExRxZ8BiLiK3vcB9nRt8reYPe0l4YmvXicUIXByVau4k=|Ashley     |Cruz      |1             |48.08       |
# |gAAAAABoP8K--5Isf-1mhR2VLeGdf_sMTjfUaa0iNlgjjnIt4-K92LCkPu5NlhX-hNMTCb-wgU1134ZFh9-osmAsyaWv6ymkpw==                    |Hannah     |Thomas    |1             |2.22        |
# |gAAAAABoP8K--5ftvk7VB2rPhhmcMjwQ2DGC7TTBtrrtSuRhK8NZcwMTXfiOM_1mAX5oWNDJBecQiGvDy6H70usuaQ1ltmBo-g==                    |Brandon    |Bridges   |1             |59.75       |
# |gAAAAABoP8K--5lvEgtK_DSp05i6nCFdP8nZuNXF7bbMx96U4WiHhcKrLT0Pv82M_LnalxtvQh7fHVX8pRZ7mirJvccU0USt4w==                    |Erika      |Mason     |1             |36.52       |
# |gAAAAABoP8K--5tHYPA7_COVI1U9Vc2xuRtVneZrUcA3yNuMcpnRCbeEQl7x2rS6HqNWsrMXjRkux-vFK3A-yKHJ-nX8eQZnp4dGjoKJazlmwPyrAXizako=|Lauren     |Anderson  |1             |207.03      |
# |gAAAAABoP8K--6e0eNeX6LcNHk7aHO-22sMP4Wy_mp8mhK_1MM0sIpKh1NBTYXFYNXGzxVFDWmaFh3GvkfLDzY8KrYJ7XNdpdwXlFwxEvL6ZcCvjqFAXZsQ=|Angela     |West      |1             |74.11       |
# |gAAAAABoP8K--6pGoXcNL3qXrD75T879RkxfYbDDUbO-zzF9UN5248nH0798WlJkt4dJT_t6RZW1_NE02AYDxhbrDI0Wks1v0EFtpbtf_gdnXXE84ge-LOY=|Cassandra  |Nunez     |1             |27.09       |
# |gAAAAABoP8K--7ClGGgkr1oYX75JDoMGQR2rOetiKH-Au_7joFS-NZpC7A7-24Y9ZdBO1YQmyj23OvhjLys1_snGTkDeR4gS6Q==                    |Morgan     |Smith     |1             |115.0       |
# |gAAAAABoP8K--7GKOhTFDcvvBha1POXvi9TO-6FpkGVEkfIEdgJzCkfCmf8nu7U2H-8bW5wncBboEWrAunrboQ3Bqb6E-5OZoj9ObJvVD_ZjCE99tWpS3KQ=|Jason      |Hernandez |1             |85.64       |
# |gAAAAABoP8K--7vTi8fOa0HgCogNXVp3lOslv8ot8huo_e41XAseXc2jxhNjHRhgf4x5Lnif5YZi_ye1nijeeNEX6-9m_tUC1Q==                    |Kevin      |Summers   |1             |132.74      |
# |gAAAAABoP8K--7vZtWh-n3mDTlChi50yOXDT2gjhcYpyvd3O7fU1J7SVjKhcG0DJOWBOR7bC0-99DL4Mf5EGPVwdZ1f9_WY-I0sj4hxWEnwH97hj1AyWccY=|Sara       |Harris    |1             |37.11       |
# |gAAAAABoP8K--8ubnHImau9td60lmQx9eP04pPEzF_L8Ts0_p4MWMiz2ogyRrPYE1TJajKEIwC4ymWAJjQnjLTRH9TbxCX4bpw==                    |Erik       |Patterson |1             |25.15       |
# |gAAAAABoP8K--8yISMDIMFNxcZcnprnAugUpXqoXpt2dtkxy-hYQvHQzLeDygHKi_6g5_wkIsCluweC8mIqGdfKVeKPnTSDXJbdIf2vqhoOFf8n8akUuqtQ=|Emily      |Hall      |1             |28.07       |
# |gAAAAABoP8K--9J4TEHC2pdbZPy0Dg9tYTXMWp2cPeQ27jPwgbUv-fT1DP-Jyk9-_wVlfawy_midscR1QxqaAKPtwHhcoxxJsCTp6OJ6mU-pX4kTd9G9UkA=|Cory       |Thomas    |1             |153.11      |
# |gAAAAABoP8K--9M_qNagWnh7fbBpiFuhdD1cyUZ5_N52U1qscQPoXuhbC11tbt3id0RgGDgeVSUvlFIF3yxB3gyfCYf6s9CIQNbNhfbAglnsuLkEtoSisDc=|Christopher|Grimes    |1             |3.51        |
# |gAAAAABoP8K--9PL9EBAkY-TMcBS44yd0-MJApeklTxLS402BFPFte_ojxGDxzLqmE08-MWPX932BecgotAcWIRQy3U_bzatyIcP1yBCPLOyAGju73fwODw=|Lisa       |Lowe      |1             |3.38        |
# |gAAAAABoP8K--9dzsXbeNErw3ND3zYCwg69EsyYr-qr74-DWPou8hijrhwvf7hxrHaQTbBjS3IKKspq0AK-4Ikmgy4omiyIvXehMFsmaOksVOrURI3IL56g=|Nathan     |Massey    |1             |54.78       |
# |gAAAAABoP8K--ARzHR6cGn2fotSZKkxWPRfHWfiKRFjZ_KD9QXhwb0pebEMArbVD3avKXkClNXy1mul9b2PfU9LDd-uyDa7UZTxeu-DBfDT2CA07OFKQ5L0=|Patricia   |Rodriguez |1             |59.94       |
# |gAAAAABoP8K--Ae4S2x_00pgDlzNxrQ1PE8JU0JquITHj7Qje6R3WtmIZRU3x41FeF2GoMNPpc32z2Ol8ku1AIByhug4aTE14TtFRh4vJ-h1JAaasEo2UlI=|David      |Everett   |1             |54.7        |
# |gAAAAABoP8K--AxUVlJTgAIKNI10XNTuyN3WbM8BdDZXQR44LaniemipAK0MDGvxYCY2R96D-eFzl2tcMvfBx3Qg-DcCZNUl1c0UFULrmTcqMdlVVPPipWE=|Tyler      |Mills     |1             |66.28       |
# |gAAAAABoP8K--ByOaDkotOvHmnohXVtePRUhojW0ICP6qXTTfvZGDBmCrf_yEoNWACGx2s6lJp7rYUT7nvFSfsxG99kf5Fak-A==                    |Natasha    |Mclaughlin|1             |124.41      |
# |gAAAAABoP8K--Bywe6dJdgyT-aiDW-f_9bTiTlTNwtSL63AmgtGZVi3YYVTx3akG874uszG6-H49nsH3Uw2fvoud28C8-2Bjs42Zq6KzusEekCw4OP7oudc=|Patricia   |Leach     |1             |38.23       |
# |gAAAAABoP8K--C5LFxb0T-Lt9rXxDds5ox9-Jn_skNqbF1EY7mcXX76mZdrup8jik30VwetAAEECN80K3yFevIor9TfMAclafTPVCi26E142_TdOa7LAEZ8=|Crystal    |Gamble    |1             |22.57       |
# |gAAAAABoP8K--CCohLoayW7clebggaQ7tPexByEQcixum3E-JkvD2nQ0gwcCnge390sVh4gs4tkppEkEPcLelKQDC0aVvP_cPA==                    |James      |Baldwin   |1             |50.74       |
# |gAAAAABoP8K--Cm6WWOcrLhNVcvILm8lTngvLvhNNBCxwjJASLhvh1AnYwQ6mVB2z6RLwB1PG6h0qy_QDUYtFdLmieAUid2GXhRD6fp6mJBRlZbs-BnczO8=|Aaron      |Stewart   |1             |29.78       |
# |gAAAAABoP8K--Cu2jN_AEMCiAcQOS-PdqHEgeYiQeCsf-eRTOhj0oGNlOeYcvAMAkTCDzuPrp4X0N-XXk5NzBKm0zkE8vAwEeQ==                    |Adam       |Santos    |1             |45.9        |
# |gAAAAABoP8K--D1c0sM90YdAaAdgPPAZQkDBmN8ev5OHLlN_frTTmOAo-Dgr8MNZmsd-xy-JM5srtzB-IzC5STXLUVSja5eWyg==                    |Helen      |Campbell  |1             |158.73      |
# |gAAAAABoP8K--D4AsHPrWLyEfqGsUtucD62s-u5PDfeTs500oSBb8tCdR4D7SY7kRo3d4uXj0HX7OJ0lGrTmecR7LbVglollZLuaVTD2wUfGrxrLTHU46bY=|Mark       |Allen     |1             |47.6        |
# |gAAAAABoP8K--DDQW4weCjjQRwv24YRw6VF1c7CpP5EJUIKqZz0SY3ad5dSj3yF3XbZ5vwjraQSwL3wYL7niK62Hp01tLtzTbA==                    |Vincent    |Waller    |1             |115.52      |
# |gAAAAABoP8K--DsIiQjHKVO7GbWJ7rx3uabKpATWr6581AWQ1g_VgsfFQ09KjZWnAWtzfE7SYUVkdDbZItCGIK3TXPC2kxIOOqfUrhTF3HyBKLQ_IOhde7A=|Allison    |Allen     |1             |155.08      |
# |gAAAAABoP8K--E17NZie0M2FImSwsrJLp8qbUbkIoMLQaRswgnagIbsNrSTmcCOQTtw8ph7eLvKbJx3g5ZoGnRW6d4ffNhoIU_zbYU9J64UJ5DLCYHZirtA=|Vanessa    |Anderson  |1             |37.81       |
# |gAAAAABoP8K--EAEMHiPc51h-z2typy0tuYp0WgTC0UJ9gYSoELTIhywS0_376e0UzBZRRru8d2SLNCoK6qNmPsXa4UgQmnQKFP80mj3btQAcsCXEa7Aoo8=|Richard    |Marshall  |1             |105.89      |
# |gAAAAABoP8K--EFWIaSxwZsm6rdzYf2JL9_GMkz-WNGLtkLi_PpRlzBnqV5BX25ILyhgpr_qlxWS3w-NPNRLLi8vdF53plfwc3w7_l-QoSsR_voUWVKAmG4=|Kimberly   |Martin    |1             |1.56        |
# |gAAAAABoP8K--EFylXG85Zn2idYJmbT9DMLVp_RuUnIyJrgyzDO_GRYkOk_BdNM-a0CD2Bb_2iq1RtN6I29PsCsUhj-FvGYXyjJnecf-TMUD3Ps_gvwEyNA=|Linda      |Gonzalez  |1             |47.11       |
# |gAAAAABoP8K--EV1yhbo2XhhkKTTBmIkjsH4NnZO_J6BEZ8JRBsgP-5gwH9uig9WRuYo589cg3c7DxFB5uzKfxUj6BTxMg25Zufsdgvv5fJQ0mAhdFNqpSs=|Maria      |Rosales   |1             |61.84       |
# |gAAAAABoP8K--Fu2QA0NH0FQkOEt1TcHxl1sqeAd1AJ9sGf0xobljD6xS-WUOUGgh5MEsdi0pMGfXNuiPkn4blMonBWNwSGm7EZ3NXtGU3sRpj6E6DZzv2g=|David      |Serrano   |1             |70.74       |
# |gAAAAABoP8K--G257P55a_CGHR3Eu38tCgDKijDSgid3ukCTNFvqPt_6aZila8IPWQgFUfLRhXp7A0kxnB4DkXxgDuEDoILaHQ==                    |Thomas     |Sullivan  |1             |57.48       |
# |gAAAAABoP8K--GE1z1w_wFa31bpSMP78bLEm2iRHmvZqYrUu7hOVHTbUAXDRRiUBbzhkobAN0KGLhY4ynSfYvnIxPIswaTDMnw==                    |Jerry      |Kelly     |1             |78.43       |
# |gAAAAABoP8K--G_eLM1ycDeZIuO9lBh4gDm2Ub4gOjqWUbQKjsTS9WMyVFBgppoJwQG82JC1v5Hvh4brCakp07qDS5Ms_Ag5X28915YAgdiQrU2bb9atMVc=|Joseph     |Davis     |1             |75.87       |
# |gAAAAABoP8K--GnzVIA5FNFTiHGXdbJHUTd3cQczaQdUmVgyEOTuAbahkR28sdrJ7MDqla9hxNw86Gnrx792WcdGAnIu2h3Vmg==                    |Casey      |Howell    |1             |98.27       |
# |gAAAAABoP8K--Gxb2PFy9YyrnytjZIpGPaflOjHCRPdmVFsx6mooFB5hWcnFfo26ilUZf8Vh9nVLsoS-qtfegeRGZmStcn5xAwFk17vcg-hN5PxYw_g-xvo=|Juan       |Sherman   |1             |34.31       |
# |gAAAAABoP8K--H5bmQMwMGyx_cBxULiQ85q5yaw1U-Kfcb-3Nii-1Yi69ay1U7XTlPPC0rkdDsYy1cI3T0YhMj_Zmik5Z-82Qg==                    |Frederick  |Robinson  |1             |16.62       |
# |gAAAAABoP8K--HHNBPXlLTC5ozIEuFVa8wR3X7ZtRw_zOQKovjK_nm7IIJQHr0w0wuP292y2sLI8OMxn51jiW-sVDna36c685Q==                    |Christopher|Patterson |1             |76.94       |
# |gAAAAABoP8K--HNPDwVjH5jRMu-tnAgGi_nRTD6P6mAvp5sy0bwJwa1Mx9obQ0zjiooYkaltMp-l8JvKp4fQNRcVPI8BJ5o-9ENBieewAOe331zb0GDLHBA=|David      |Bonilla   |1             |70.81       |
# |gAAAAABoP8K--Hd1f-nd6KEsI--ztCBa0WNdGisikfrFCA8i_UpkVoahua-HBBfj2_ua5VFVrjV9skmrWKAIG9_hX8dywWWiN8gmRYdoxJp4QXGLvz6Wy4U=|Julia      |Bell      |1             |52.76       |
# |gAAAAABoP8K--HnKv2xKd4Ep1wb96pZLFZGAqf4aHggWnEpafKppA36XnqRPduc1_FYuMSCE1vjujZoeurzxmmgMjEfxq_eYPQ==                    |David      |Kirby     |1             |42.46       |
# |gAAAAABoP8K--HorsKb2EIoql-MVGtk9DnWyBU1rVbQhDs1u9NYM6SVGj-uOVRhn0S5jdkiuhrYeZ0nBq5noSkNTCQhRL0E3Y_x52ZydobeZ-OjnuBQI02A=|Angela     |Taylor    |1             |102.81      |
# |gAAAAABoP8K--I7jDuucgnjy7VSOyaQhjkrla3vkcq1xAUjwDJ-OIV3QR1Pwf9U4QZsJbMgh9YhLXNTWrf1nmStJxHJ0yfttIQ==                    |John       |Peters    |1             |57.88       |
# |gAAAAABoP8K--IRXIkK89JRMNXvT-oz7iGQSJ7yGbxuMbavA7jaGiq9LcHC5ErE3GZvIMkfywGiui19V627iw069WKTsaMfYcpwCoWTxZKhLgl4JbRawRrQ=|Linda      |Davis     |1             |28.64       |
# |gAAAAABoP8K--IYfzbYqRrWgL13foLfQ8t4gnOi5XzdsPztTtpFTLQPQmeIskCOabeqW_ZjcXT4taKLAQcRh_Dwn4zNuK1CojKMtOEEY0dPOlxnRk2hiTrs=|Kristina   |Stewart   |1             |271.24      |
# |gAAAAABoP8K--ItzdJ_XcSnaoj35Inpfhc-ZPCpQ9NfZ_q9IpG7Mu9gqdcGLmM_OUHGC4LtLCV8nkXk1afU0UF-eMP04JMan9gvrMh8XURVWo4qEerUFbP8=|Wayne      |Marsh     |1             |80.01       |
# |gAAAAABoP8K--IyMcl0WqBDLWD8oJt8sHUVLG01-qnwhENLsUrhq_biENmKB7oSlsPl54nmN4b-pZYx8V7GKRgPtENsDj9lVQ4tIGCV0_7rPs2wrhOY4zSI=|Walter     |Blair     |1             |57.9        |
# |gAAAAABoP8K--J1kJCFBgkFNA_Sqm5wz43uPV4IJLrUkJ2d0fG0B6czQPUYvo_T6no6Wav2lwKix9M5qdVLOtMO-6KjX8NW5JItdWT7bdM-o7TH5zKYGPY0=|Allen      |Bell      |1             |56.04       |
# |gAAAAABoP8K--JT7x1FDKJa9Vvx12P02U5QgNjgOOQlBzPXox0KNQ553rVYO-MJ2vh5DlWgTcS9F0rKPIRQNLSNf8CPFN8fbzjbqWzcMybihUIB-uBP2gJA=|Barbara    |Lowe      |1             |9.54        |
# |gAAAAABoP8K--JYjT-WgHHfQQyzN3n09cOYCEsoYz8ce-q6ez-DIupZYP4IKhZFmHjyYV80-5ngSPzsigGnOEQMFR3m0ugy-Ba5Je8B2JyLJwEGE-6rgcoE=|Margaret   |Mendez    |1             |8.45        |
# |gAAAAABoP8K--JZcHsFvXztSPkIVDwGZ5BO6SCsNTKtm06CxyQR3otCFO0LthAJdDf99KwAfXoFdHFmB1e1Dx3Apd1FB6UHW_s-JEu5U4yuzbnU0WkZLg8g=|Angela     |West      |1             |7.42        |
# |gAAAAABoP8K--K4TJWkii8ZfxPwU2lHAgZG-VrLOtRggEzLU3pKsNueJHGLMBRa6AF6G6aXugDBW3T2RLdBCh0E5opzQfTN0qwrqhW53bwNKtgB216RiuNk=|Renee      |Parrish   |1             |26.48       |
# |gAAAAABoP8K--KJBtwMvvRP38Zb6iuwVlI1ETywaOR6Y3BOVjm3rYjyYsgAzBMGqm3-TYT9sXuVFto36tW7KAeTsY-3X83lL4piu8jketKOlVapqYEo9x3A=|Laura      |Walker    |1             |43.5        |
# |gAAAAABoP8K--KS2g_7J441fthU642IGO7hItxelFYKIdM9gKWpBC8p5c3CN1VPHsoN6x2-T1MB-2TrnuY4nsA2Cyn--PwUVnboEkXfohUl6ezGFva-GH4U=|Daniel     |Cain      |1             |77.84       |
# |gAAAAABoP8K--KVWvP17HTZE9SO2VWvMd_0FBCr3gPlEZWK0gW9_ppUGJel_XnNvR6aKjRBi3I8QC-2kLVgz9GocLLK5Z2Z4qg==                    |Michael    |Rodriguez |1             |49.32       |
# |gAAAAABoP8K--KXYAEblUgQjNaTcHVxw2ixtZISuDE_eTQlbH2u48To7EauVSFx94B2IqX7isvvy8RjGGGsRDbkOiVHsfMxLWg==                    |Rachel     |Lowe      |1             |45.79       |
# |gAAAAABoP8K--L9iFUvnJZfDzRFMnXP53Oh28xo7WP1TbMZY6G3ROkDRAhckbO5mMrfHP5Lt4ppivIZ6vasZjlp6nriX0tWTSA==                    |Dale       |Smith     |1             |5.57        |
# |gAAAAABoP8K--LC25rRpFs9kBikkM6T43wqzpbq1hHJMZoC9eqxQBkWRNMYiVinoxmqtTwwEwxVPFAg85zJjJRpoxXsXuTIWwQ==                    |Brandy     |Quinn     |1             |9.93        |
# |gAAAAABoP8K--LOhyGp3clkPJ9MfI_m1EWVbkApBp6Z3iYFmF4aHcBRrLD769-etNNfBw5y2pcYREO6ixTaL2_VcASNxNjMTzg==                    |Danielle   |Evans     |1             |13.32       |
# |gAAAAABoP8K--LicYDFw0Zct6fo4ouQsRD38dUbVLcpiYgEgqUgQS_6wFPR9ZWHxDJNTfgwg8kFaLwF91arAar8bhbWH1E21pgou8HPfzME2yJUuMY3sfz8=|Brenda     |Perez     |1             |7.09        |
# |gAAAAABoP8K--LmfPzm9VLgiQ6VeECDL7_X1PBOYqvN9zdZIMT0z5GH2EMVOQ-A4ExzqKpFlXcZZWMeGNcgqPHBSDT4mGfijuw==                    |Daniel     |Briggs    |1             |5.28        |
# |gAAAAABoP8K--LtqudzguNyZrviQMrMBkzcT_IWDybPjzWtHl4-XkFYOWvlEsyOam8g_ZEoULE5ADd0zKNZuOluZJwCnUT95wguk44MK2i5oYVvxoPgI-8M=|Tammy      |Ayers     |1             |75.67       |
# |gAAAAABoP8K--M-Wfy88EzAoS4WGS6CiRYdrNUNawqoIt7AwHzPOYjcdHY-baDTwXHeGIHPjB62vdldAIbYt3B4xdqxlFYN7-UJU66R_rpW-HrN1WWIwXk0=|David      |Serrano   |1             |96.25       |
# |gAAAAABoP8K--M4U4dD1AMQH_Grv8DuCa0lyvl_k9jcfy2Wbwgc9NYGE0iOI4LE92fnx6O_ycyryE-9tvpKLr9eJrYqn0V83RQn9gGr_eDMc8rNIdSVDZxA=|Joseph     |Davis     |1             |75.67       |
# |gAAAAABoP8K--MHxz1D7RVFt-CqEZwaep-sAKNmunTIhKuJnUE0l0W-HRfOPU3IThvWEE2mIIzW5Y4Gk2RYUO7SYjJ6kNOWsJw==                    |Andrew     |Tucker    |1             |27.64       |
# |gAAAAABoP8K--MaVsXXRyxWkTDje41KA9zM3Vz90Sp-7jJLZLrq9Uk_bLaUxoK0jt7d4gYFTXmGdiZkKWyKTunpgDJzua3NhyQ==                    |Thomas     |Sullivan  |1             |7.48        |
# |gAAAAABoP8K--MfJY467XoXP-mqB9taw2uRX8ckZe3uUpQRr7hOQGzSX-nsEypbS1I5kuDTZ3mTJLlr5BWzgC050vv4pPbPADATEN5H0OPPg8RA2HkK2pbY=|Jonathan   |Castro    |1             |38.76       |
# |gAAAAABoP8K--MkEzeMOEDJJVYTJ-hdmKtvwULeqJalBUi4Tkd9-FsAMy6_cvsGYUJw6OKjMmsLFymIqwFoZ-UXEUR4IErSDL7NWYkuHlTtg8MZuX3c12L0=|Michelle   |Johnston  |1             |127.82      |
# |gAAAAABoP8K--MoWQOWjZluY0xvD1llET8InMgAD1us9MHSbpe9ZoRl9Ds5uTGCic8wPpY3NcqJd3nCGC4sfi2vUH9p-KxVdTcLnmzm1WiimSLZ-6WDYeBQ=|Dawn       |Gray      |1             |68.65       |
# |gAAAAABoP8K--MxHKrTwVwrDh4onuyrinDiDNwnDQXeIKtiFGk3NB7dnqHPNCid-dSmYody3AY3c0RhtilrwaR7j8oBbpIfAwA==                    |Brandon    |Bridges   |1             |56.2        |
# |gAAAAABoP8K--N964Y_sX1Or_inZNUJY0Hs5k2V_lfa0t4NxOmL0VptN3q7mzGP8BpPQKn9gzB2exljVar31lXsHkGDxZBn09ERkDaLNTTfVEknX6rltonk=|David      |Rogers    |1             |20.17       |
# +------------------------------------------------------------------------------------------------------------------------+-----------+----------+--------------+------------+
# only showing top 100 rows
