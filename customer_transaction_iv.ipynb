# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pyspark.sql import SparkSession,DataFrame
from pyspark.sql.functions import udf,col,split,explode_outer,regexp_replace,from_json,date_format,to_timestamp,expr,from_utc_timestamp,lit
from pyspark.sql.types import DoubleType,StructType, StructField, ArrayType, StringType, TimestampType
import pytz
from cryptography.fernet import Fernet

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
import matplotlib.pyplot as plt
import os

# %%
def flatten_json(df):

    """
    Flattens a DataFrame with complex nested fields (Arrays and Structs) by converting them into individual columns.
   
    Parameters:
    - df: The input DataFrame with complex nested fields
   
    Returns:
    - The flattened DataFrame with all complex fields expanded into separate columns.
   """
   # compute Complex Fields (Lists and Structs) in Schema   
    complex_fields = dict([(field.name, field.dataType,)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
    print(df.schema)
    print("")
    while len(complex_fields)!=0:
      col_name=list(complex_fields.keys())[0]
      print ("Processing :"+col_name+" Type : "+str(type(complex_fields[col_name])))

      # if (type(complex_fields[col_name]) == StringType):
          # print(col_name)
          # print(df.withColumn("new_col",startswith(col_name[0],'{')))
          # print("true")
      # if StructType then convert all sub element to columns.
      # i.e. flatten structs
      if (type(complex_fields[col_name]) == StructType) :
         expanded = [col(col_name+'.'+k).alias(col_name+'_'+k) for k in [ n.name for n in  complex_fields[col_name]]]
         df=df.select("*", *expanded).drop(col_name)
    
      # if ArrayType then add the Array Elements as Rows using the explode function
      # i.e. explode Arrays
      elif (type(complex_fields[col_name]) == ArrayType):    
         df=df.withColumn(col_name,explode_outer(col_name))
    
      # recompute remaining Complex Fields in Schema       
      complex_fields = dict([(field.name, field.dataType)
                             for field in df.schema.fields
                             if type(field.dataType) == ArrayType or  type(field.dataType) == StructType])
    return df

# %%
# Create SparkSession 
spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()

# %%
# localTime = pytz.timezone("Malaysia/Kuala_Lumpur") 
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        #bronze_df to load to datalake/data storage. Bronze layer usually is one to one with source
        bronze_df = spark.read.format("json").load(os.path.join(dirname, filename))
        bronze_row = bronze_df.count()
        print(f"Bronze DataFrame Rows count : {bronze_row}")
        # bronze_df.write.format("delta").mode("append").save(os.path.join(dirname, "cc_sample_transaction1.json"))
# Out:
# /kaggle/input/cc-sample-data/cc_sample_transaction.json
# Bronze DataFrame Rows count : 1296675

# %% [markdown]
# Identify dirty data can be done by execu distinct attributes to find the pattern of the values that can be excluded to make the data clean and valuable. For example for name, we should not expect any symbol or number. You can also use data profiling tools to get the summary of your data to check of consistency and correctness.
# For attributes that must not be nullable, if null exist it will make the data become invalid, we can remove it in transformation layer. Similarly with duplicates data, can be removed/excluded in transformation layer.

# %%
        # Initially can execute bronze_df.printSchema() to get the schema to predefined the attributes.
        #Defines the schemas of the attributes
        personal_detail_schemas = StructType([StructField("person_name", StringType(), True),
                    StructField("gender", StringType(), True),
                    StructField("address", StringType(), True),          
                    StructField("lat", StringType(), True),
                    StructField("long", StringType(), True),
                    StructField("city_pop", StringType(), True),
                    StructField("job", StringType(), True),
                    StructField("dob", StringType(), True)],
                    )
        address_schemas =  StructType([StructField("street", StringType(), True),
                                                        StructField("city", StringType(), True),
                                                        StructField("state", StringType(), True),
                                                        StructField("zip", StringType(), True)])
        #Transformed the data into the preferable data type and format
        bronze_df=bronze_df.withColumn("merch_eff_time",bronze_df.merch_eff_time.cast(DoubleType()))\
        .withColumn("merch_last_update_time",bronze_df.merch_last_update_time.cast(DoubleType()))\
        .withColumn("personal_detail", from_json(col("personal_detail"), personal_detail_schemas))
        bronze_df=bronze_df.withColumn("merch_eff_time",date_format(to_timestamp(bronze_df["merch_eff_time"]/1000000) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))\
        .withColumn("merch_last_update_time",date_format(to_timestamp(bronze_df["merch_last_update_time"]/1000) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))\
        .withColumn("address", from_json(col("personal_detail.address"), address_schemas))\
        .withColumn("trans_date_trans_time",date_format(to_timestamp(bronze_df["trans_date_trans_time"]) + expr("INTERVAL 8 HOURS"),"yyyy-mm-dd HH:mm:ss.SSSS Z"))
        # df.select(col("merch_last_update_time"),col("merch_eff_time"),col("trans_date_trans_time")).show(n=30,truncate=False)
        flatten_df = flatten_json(bronze_df)
        # flatten_df.select(col("personal_detail_person_name"),col("merch_last_update_time"),col("merch_eff_time"),col("trans_date_trans_time")).show(n=100,truncate=False)
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], ", !",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "!",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"],", ,",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"],", ",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], ",eeeee",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], " NOOOO",""))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "@",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "/",","))
        flatten_df = flatten_df.withColumn("personal_detail_person_name",regexp_replace(flatten_df["personal_detail_person_name"], "\|",","))
        # flatten_df.select(col("personal_detail_person_name")).show(n=100,truncate=False)
        flatten_df = flatten_df.withColumn("personal_detail_person_name", split(flatten_df["personal_detail_person_name"], ',\s*'))
        flatten_df = flatten_df.withColumn("first", flatten_df["personal_detail_person_name"][0])\
        .withColumn("last", flatten_df["personal_detail_person_name"][1])
        # flatten_df.select(col("first"),col("last")).show(n=100,truncate=False)
        flatten_df = flatten_df.drop("personal_detail_address")\
        .drop("personal_detail_person_name")
        flatten_df = flatten_df.withColumnsRenamed({
        "personal_detail_gender": "gender",
        "personal_detail_lat": "lat",
        "personal_detail_long": "long",
        "personal_detail_city_pop": "city_pop",
        "personal_detail_job": "job",
        "personal_detail_dob": "dob",
        "address_street": "street",
        "address_city": "city",
        "address_state": "state",
        "address_zip": "zip"
        })
# Out:
# StructType([StructField('Unnamed: 0', StringType(), True), StructField('amt', StringType(), True), StructField('category', StringType(), True), StructField('cc_bic', StringType(), True), StructField('cc_num', StringType(), True), StructField('is_fraud', StringType(), True), StructField('merch_eff_time', StringType(), True), StructField('merch_last_update_time', StringType(), True), StructField('merch_lat', StringType(), True), StructField('merch_long', StringType(), True), StructField('merch_zipcode', StringType(), True), StructField('merchant', StringType(), True), StructField('personal_detail', StructType([StructField('person_name', StringType(), True), StructField('gender', StringType(), True), StructField('address', StringType(), True), StructField('lat', StringType(), True), StructField('long', StringType(), True), StructField('city_pop', StringType(), True), StructField('job', StringType(), True), StructField('dob', StringType(), True)]), True), StructField('trans_date_trans_time', StringType(), True), StructField('trans_num', StringType(), True), StructField('address', StructType([StructField('street', StringType(), True), StructField('city', StringType(), True), StructField('state', StringType(), True), StructField('zip', StringType(), True)]), True)])
#
# Processing :personal_detail Type : <class 'pyspark.sql.types.StructType'>
# Processing :address Type : <class 'pyspark.sql.types.StructType'>

# %% [markdown]
# For Handling PII data, We can encrypt it using aes_encrypt library or fernet library in the transformation/silver layer. In this task, I used aes_encrypt library for simplicity. The key you create a secret key and parse it in the key parameter. For this task, I hard coded the key value. For bronze layer, we can manage it by adding a role based access control (rbac) to restrict only certain user can access it. Potentially only system can access. Each individual are restricted in to access the PII only upon request and the request has been justified and approved by managers.

# %%
        enc_df = flatten_df.withColumn('encrypted_cc_num', expr("base64(aes_encrypt(cc_num, '1234567890abcdef', 'ECB', 'PKCS'))"))
        enc_df = enc_df.orderBy("cc_num")
        enc_df.show(n=20,truncate=False)
# Out:
# +----------+------+--------------+-----------+---------------+--------+------------------------------+------------------------------+------------------+----------+-------------+-------------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+----------------------+----------+---------------------+----------+-----+-----+-----+----+------------------------+
# |Unnamed: 0|amt   |category      |cc_bic     |cc_num         |is_fraud|merch_eff_time                |merch_last_update_time        |merch_lat         |merch_long|merch_zipcode|merchant                             |trans_date_trans_time         |trans_num                       |gender|lat    |long    |city_pop|job                   |dob       |street               |city      |state|zip  |first|last|encrypted_cc_num        |
# +----------+------+--------------+-----------+---------------+--------+------------------------------+------------------------------+------------------+----------+-------------+-------------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+----------------------+----------+---------------------+----------+-----+-----+-----+----+------------------------+
# |11377     |71.25 |health_fitness|NA         |180011453250192|0       |2012-03-08 02:03:11.9678 +0000|2012-03-08 02:03:11.7810 +0000|40.643858         |-90.774282|61475        |fraud_Dare-Gibson                    |2019-03-08 02:03:11.0000 +0000|3a72c24d360b40f00ae6d14e9731de1a|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1266346   |59.8  |food_dining   |CITIUS33CHI|180011453250192|0       |2013-54-10 05:54:04.4913 +0000|2013-54-10 05:54:04.6370 +0000|41.129174         |-90.040051|61434        |fraud_Kuhn Group                     |2020-54-10 05:54:04.0000 +0000|258a2c35cd4fee63b7f8a66302740610|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1092160   |110.24|grocery_pos   |Null       |180011453250192|0       |2013-56-30 14:56:00.6070 +0000|2013-56-30 14:56:00.6020 +0000|41.736158         |-91.688981|52340        |fraud_Rau and Sons                   |2020-56-30 14:56:00.0000 +0000|caf72e94a22e54e9f1406eb7e21a2ff3|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1262336   |41.76 |kids_pets     |Null       |180011453250192|0       |2013-08-09 05:08:13.2681 +0000|2013-08-09 05:08:13.5830 +0000|42.040865         |-91.189365|52312        |fraud_Daugherty LLC                  |2020-08-09 05:08:13.0000 +0000|6910a050c203931094cd41e61660c4be|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |908825    |69.73 |food_dining   |CITIUS33CHI|180011453250192|0       |2012-21-29 05:21:21.9784 +0000|2012-21-29 05:21:21.2600 +0000|41.745693         |-91.876334|52236        |fraud_Schumm, McLaughlin and Carter  |2019-21-29 05:21:21.0000 +0000|f8c1b84112388e79a4a78286beae0431|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
#
M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1266650   |83.17 |personal_care |CITIUS33CHI|180011453250192|0       |2013-30-10 07:30:28.1869 +0000|2013-30-10 07:30:28.3700 +0000|40.600225         |-91.02416 |61450        |fraud_Shanahan-Lehner                |2020-30-10 07:30:28.0000 +0000|d7273e9a8b7a6ed1abc9224e4610a59b|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |547091    |73.5  |entertainment |CITIUS33CHI|180011453250192|0       |1974-53-07 18:53:45.2619 +0000|2012-57-22 20:57:32.1540 +0000|40.287951         |-91.804178|63473        |fraud_Stark-Batz                     |2019-57-22 20:57:32.0000 +0000|22e2d26484726a94955b985be89e51c2|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1266694   |52.72 |kids_pets     |DEUTUS33TRF|180011453250192|0       |2013-44-10 07:44:05.6015 +0000|2013-44-10 07:44:05.2200 +0000|40.961782         |-90.180233|61428        |fraud_Hilpert-Conroy                 |2020-44-10 07:44:05.0000 +0000|49d379ae06b0d3e1fea42611b2ecc6b0|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1093372   |45.11 |kids_pets     |NA         |180011453250192|0       |2013-34-31 00:34:03.7043 +0000|1974-15-29 19:15:24.3230 +0000|41.720838         |-91.036713|52721        |fraud_Hammes-Beatty                  |2020-34-31 00:34:03.0000 +0000|748ec83aa1a7b0a94db3033a725709a2|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# |1266775   |53.14 |grocery_net   |ADMDUS41   |180011453250192|0       |2013-32-10 08:32:10.4350 +0000|2013-32-10 08:32:10.9780 +0000|40.724531         |-91.460361|52656        |fraud_Emmerich-Luettgen              |2020-32-10 08:32:10.0000 +0000|af41b6de47392fc346bddb7f12d138b6|M     |41.2153|-90.9879|1504    |Manufacturing engineer|1993-10-05|721 Jacqueline Brooks|New Boston|IL   |61272|Craig|Dunn|Zb1uhqfjU9MV5Xtj8vZdSg==|
# +----------+------+--------------+-----------+---------------+--------+------------------------------+------------------------------+------------------+----------+-------------+-------------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+----------------------+----------+---------------------+----------+-----+-----+-----+----+------------------------+
# only showing top 20 rows

# %%
        #Decrypt data if required by using below script
        # dec_df = enc_df.withColumn('decrypted_cc_num', expr("aes_decrypt(unbase64(encrypted_cc_num), '1234567890abcdef', 'ECB', 'PKCS')").cast("STRING"))

        #silver_df layer is after the data being transformed and cleaned
        silver_df = enc_df.dropDuplicates()
        silver_row = silver_df.count()
        print(f"Silver DataFrame Rows count : {silver_row}")
        silver_df.show(n=20,truncate=False)
# Out:
# Silver DataFrame Rows count : 1296675
# +----------+------+--------------+-----------+----------------+--------+------------------------------+------------------------------+------------------+------------------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+--------------------------------------+----------+-------------------------------+----------------+-----+-----+-----------+---------+--------------------------------------------+
# |Unnamed: 0|amt   |category      |cc_bic     |cc_num          |is_fraud|merch_eff_time                |merch_last_update_time        |merch_lat         |merch_long        |merch_zipcode|merchant                          |trans_date_trans_time         |trans_num                       |gender|lat    |long    |city_pop|job                                   |dob       |street                         |city            |state|zip  |first      |last     |encrypted_cc_num                            |
# +----------+------+--------------+-----------+----------------+--------+------------------------------+------------------------------+------------------+------------------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+--------------------------------------+----------+-------------------------------+----------------+-----+-----+-----------+---------+--------------------------------------------+
# |6625      |6.76  |misc_net      |CITIUS33CHI|4155021259183870|0       |2012-15-05 16:15:16.3292 +0000|2012-15-05 16:15:16.8170 +0000|35.054472         |-99.187648        |73655        |fraud_Stehr, Jewess and Schimmel  |2019-15-05 16:15:16.0000 +0000|63ba398bd1b6a4df3aa54255692aee56|F     |34.7032|-98.9591|540     |Research scientist (life sciences)    |1983-10-12|174 Jennifer Meadow Apt. 467   |Mountain Park   |OK   |73559|Renee      |Parrish  |7p01WF/Iu8mzUcVIOiCoYALexWUsAhX5OvafAJ8PbVg=|
# |6901      |71.59 |shopping_pos  |Null       |3502088871723054|0       |2012-51-05 21:51:13.9996 +0000|2012-51-05 21:51:13.1580 +0000|38.536369         |-76.724638        |20637        |fraud_Lesch Ltd                   |2019-51-05 21:51:13.0000 +0000|7c2b5e75d10f54c9d63aafe1225b599c|M     |39.0298|-77.0793|19054   |Operations geologist                  |1976-09-08|31472 Cody Place Suite 740     |Kensington      |MD   |20895|Scott      |Martin   |Q/hZGHuqJWhCcH4taE0u4ALexWUsAhX5OvafAJ8PbVg=|
# +----------+------+--------------+-----------+----------------+--------+------------------------------+------------------------------+------------------+------------------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+--------+--------+--------------------------------------+----------+-------------------------------+----------------+-----+-----+-----------+---------+--------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# to identify the potential customer based on the number of registered credit card in each state

# %%
        table = spark.sql('''
        select state, count(distinct cc_num) as num_of_cc
        from {tb}
        group by state order by 2 desc limit 5
        ''', tb=silver_df)
        table.show(n=500,truncate=False)
# Out:
# +-----+---------+
# |state|num_of_cc|
# +-----+---------+
# |NY   |71       |
# |TX   |66       |
# |PA   |58       |
# |CA   |45       |
# |OH   |39       |
# +-----+---------+

# %%
        data = table.toPandas()
        plt.bar(data.state,data.num_of_cc)
        plt.title("Registered Customer")

        # Setting the X and Y labels

        plt.xlabel('state')

        plt.ylabel('num_of_cc')

        # Adding the legends

        plt.show()

# %% [markdown]
# to identify customer credit card use for potential fraud or suspicious use

# %%
        #to identify credit card use for fraud
        table2 = spark.sql('''
        select *
        from {tb}
        where is_fraud = '1'
        ''', tb=silver_df)
        table2.drop('cc_num').show(n=5,truncate=False)
# Out:
# +----------+------+------------+-----------+--------+------------------------------+------------------------------+---------+----------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+---------+--------+--------------------------------------+----------+-----------------------------+--------+-----+-----+--------+-------+--------------------------------------------+
# |Unnamed: 0|amt   |category    |cc_bic     |is_fraud|merch_eff_time                |merch_last_update_time        |merch_lat|merch_long|merch_zipcode|merchant                          |trans_date_trans_time         |trans_num                       |gender|lat    |long     |city_pop|job                                   |dob       |street                       |city    |state|zip  |first   |last   |encrypted_cc_num                            |
# +----------+------+------------+-----------+--------+------------------------------+------------------------------+---------+----------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+---------+--------+--------------------------------------+----------+-----------------------------+--------+-----+-----+--------+-------+--------------------------------------------+
# |36187     |746.76|shopping_pos|CITIUS33CHI|1       |2012-12-22 10:12:36.4539 +0000|1974-37-17 10:37:15.6280 +0000|28.213586|-80.990412|34773        |fraud_Friesen Inc                 |2019-12-22 10:12:36.0000 +0000|00422000408aea213f6432061686b0bd|F     |27.4703|-81.4872 |50835   |Environmental consultant              |1986-01-30|2924 Bobby Trafficway        |Sebring |FL   |33872|Joanna  |Hudson |XJBGSxDnoaQOIexdKh9cxg==                    |
# |51277     |801.76|shopping_pos|ADMDUS41   |1       |2012-37-31 07:37:19.7669 +0000|2012-37-31 07:37:19.4910 +0000|29.554999|-82.064213|32640        |fraud_Daugherty, Pouros and Beahan|2019-37-31 07:37:19.0000 +0000|0323b65a0079beba3ea20248864e7f9a|M     |29.8575|-82.1483 |2060    |Oncologist                            |1983-11-10|03921 Cole Mission Suite 882 |Hampton |FL   |32044|Ryan    |Foster |ShZNia/Ov79O59GKlogFPgLexWUsAhX5OvafAJ8PbVg=|
# |132092    |1054.9|shopping_net|CITIUS33CHI|1       |2012-33-14 07:33:02.8218 +0000|2012-33-14 07:33:02.6860 +0000|42.117389|-73.255804|01259        |fraud_Fisher Inc                  |2019-33-14 07:33:02.0000 +0000|85c2b2443cdc822518a337880fdacf62|M     |41.5097|-73.9634 |19880   |Lawyer                                |1962-11-15|24809 Cross Creek            |Beacon  |NY   |12508|Larry   |Garcia |A2Zw6GLyuLG33Vbo6lVjKALexWUsAhX5OvafAJ8PbVg=|
# |135723    |951.58|shopping_net|AIABUS31   |1       |2012-35-16 06:35:20.3068 +0000|2012-35-16 06:35:20.4550 +0000|40.057229|-109.76986|84063        |fraud_Baumbach, Feeney and Morar  |2019-35-16 06:35:20.0000 +0000|dc835c8a926bb813110881ced7cb9f61|M     |41.0552|-110.1603|49      |Research scientist (physical sciences)|1981-07-05|529 Joshua Knoll Apt. 511    |Lonetree|WY   |82936|Robert  |Long   |bwpw3i6v2nOvj1xIOSEH6gLexWUsAhX5OvafAJ8PbVg=|
# |24189     |310.15|grocery_pos |AIABUS31   |1       |2012-35-15 08:35:28.2758 +0000|2012-35-15 08:35:28.5480 +0000|36.093631|-83.634203|37871        |fraud_Kiehn Inc                   |2019-35-15 08:35:28.0000 +0000|ebb5509aa63a5c90e17f25c1f3afd41d|M     |36.115 |-84.0438 |4729    |Geologist, wellsite                   |1982-04-19|2123 Jonathan Falls Suite 753|Heiskell|TN   |37754|Nicholas|Mcmahon|Vk4lkazO7N2a7s3PfSTEXQLexWUsAhX5OvafAJ8PbVg=|
# +----------+------+------------+-----------+--------+------------------------------+------------------------------+---------+----------+-------------+----------------------------------+------------------------------+--------------------------------+------+-------+---------+--------+--------------------------------------+----------+-----------------------------+--------+-----+-----+--------+-------+--------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# number of credit cards that are potentialy fraudulent or suspicious in each state.

# %%
        table3 = spark.sql('''
        select state, count(distinct cc_num) as num_of_cc
        from {tb}
        where is_fraud = '1'
        group by state order by 2 desc limit 5
        ''', tb=silver_df)
        table3.show(n=500,truncate=False)
# Out:
# +-----+---------+
# |state|num_of_cc|
# +-----+---------+
# |NY   |56       |
# |TX   |51       |
# |PA   |46       |
# |CA   |37       |
# |OH   |32       |
# +-----+---------+

# %%
        data3 = table3.toPandas()
        plt.bar(data3.state,data3.num_of_cc)
        plt.title("Quantity of Fraud CC")

        # Setting the X and Y labels

        plt.xlabel('state')

        plt.ylabel('num_of_cc')

        # Adding the legends

        plt.show()

# %% [markdown]
# Identify which segment customer usage of credit card to offer better credit card plan / type for better customer satisfaction

# %%
        table4 = spark.sql('''
        with cust_transaction as (select encrypted_cc_num, first, last, category, count(*) as category_count, sum(amt) as total_amount
        from {tb}
        where is_fraud = '0'
        group by 1,2,3,4
        )
        select substr(encrypted_cc_num,1,10), first, last,category,category_count,total_amount from (
        select *, rank() over (partition by encrypted_cc_num order by total_amount desc) rnk from cust_transaction)
        where rnk <=5 
        order by encrypted_cc_num,total_amount desc
        
        ''', tb=silver_df)
        table4.show(n=100,truncate=False)
# Out:
# +-------------------------------+---------+---------+--------------+--------------+------------------+
# |substr(encrypted_cc_num, 1, 10)|first    |last     |category      |category_count|total_amount      |
# +-------------------------------+---------+---------+--------------+--------------+------------------+
# |++QunQw8pI                     |Jennifer |Conner   |grocery_pos   |48            |5958.2699999999995|
# |++QunQw8pI                     |Jennifer |Conner   |gas_transport |79            |4891.649999999999 |
# |++QunQw8pI                     |Jennifer |Conner   |shopping_net  |46            |4070.6400000000003|
# |++QunQw8pI                     |Jennifer |Conner   |home          |43            |2748.15           |
# |++QunQw8pI                     |Jennifer |Conner   |personal_care |41            |2263.6499999999996|
# |+/3PSFbyNT                     |Monique  |Robinson |grocery_pos   |144           |13207.21          |
# |+/3PSFbyNT                     |Monique  |Robinson |kids_pets     |153           |12524.64          |
# |+/3PSFbyNT                     |Monique  |Robinson |gas_transport |160           |11308.919999999998|
# |+/3PSFbyNT                     |Monique  |Robinson |home          |165           |10683.669999999998|
# |+/3PSFbyNT                     |Monique  |Robinson |travel        |66            |10220.23          |
# |+4d34U1dnH                     |Kimberly |Castro   |grocery_pos   |42            |5230.09           |
# |+4d34U1dnH                     |Kimberly |Castro   |gas_transport |75            |4569.92           |
# |+4d34U1dnH                     |Kimberly |Castro   |misc_net      |31            |3693.1699999999996|
# |+4d34U1dnH                     |Kimberly |Castro   |home          |48            |2988.9100000000003|
# |+4d34U1dnH                     |Kimberly |Castro   |kids_pets     |48            |2928.45           |
# |+7Da82l04M                     |David    |Bonilla  |travel        |32            |16304.97          |
# |+7Da82l04M                     |David    |Bonilla  |shopping_pos  |96            |13075.889999999998|
# |+7Da82l04M                     |David    |Bonilla  |grocery_pos   |122           |12133.580000000002|
# |+7Da82l04M                     |David    |Bonilla  |home          |123           |9739.81           |
# |+7Da82l04M                     |David    |Bonilla  |shopping_net  |80            |7576.61           |
# |+7N2dhnyqf                     |Karen    |Johnson  |grocery_pos   |103           |13289.79          |
# |+7N2dhnyqf                     |Karen    |Johnson  |gas_transport |155           |9361.010000000002 |
# |+7N2dhnyqf                     |Karen    |Johnson  |misc_net      |67            |6287.399999999999 |
# |+7N2dhnyqf                     |Karen    |Johnson  |shopping_net  |82            |6098.710000000001 |
# |+7N2dhnyqf                     |Karen    |Johnson  |shopping_pos  |74            |5752.030000000001 |
# |+HaBNj6RPy                     |Daniel   |Melton   |grocery_pos   |99            |13070.75          |
# |+HaBNj6RPy                     |Daniel   |Melton   |gas_transport |158           |9482.970000000001 |
# |+HaBNj6RPy                     |Daniel   |Melton   |travel        |37            |8381.380000000001 |
# |+HaBNj6RPy                     |Daniel   |Melton   |kids_pets     |105           |4936.57           |
# |+HaBNj6RPy                     |Daniel   |Melton   |shopping_pos  |76            |4589.629999999999 |
# |+PYuF3V0Xg                     |David    |Rodriguez|gas_transport |242           |16645.31          |
# |+PYuF3V0Xg                     |David    |Rodriguez|home          |270           |16429.16          |
# |+PYuF3V0Xg                     |David    |Rodriguez|shopping_net  |173           |15180.920000000004|
# |+PYuF3V0Xg                     |David    |Rodriguez|grocery_pos   |235           |13935.640000000001|
# |+PYuF3V0Xg                     |David    |Rodriguez|kids_pets     |197           |11827.35          |
# |+SVI6Gn1n5                     |Patricia |Leach    |grocery_pos   |92            |18706.47          |
# |+SVI6Gn1n5                     |Patricia |Leach    |shopping_pos  |135           |11211.48          |
# |+SVI6Gn1n5                     |Patricia |Leach    |shopping_net  |112           |11024.16          |
# |+SVI6Gn1n5                     |Patricia |Leach    |entertainment |59            |6396.72           |
# |+SVI6Gn1n5                     |Patricia |Leach    |misc_pos      |61            |5756.03           |
# |+pRGm+sE+x                     |Matthew  |Young    |grocery_pos   |164           |14644.94          |
# |+pRGm+sE+x                     |Matthew  |Young    |kids_pets     |156           |11520.23          |
# |+pRGm+sE+x                     |Matthew  |Young    |gas_transport |157           |10813.960000000001|
# |+pRGm+sE+x                     |Matthew  |Young    |food_dining   |109           |8453.65           |
# |+pRGm+sE+x                     |Matthew  |Young    |home          |122           |7240.7            |
# |+t6qVFJfNz                     |Gloria   |Wallace  |travel        |13            |11937.26          |
# |+t6qVFJfNz                     |Gloria   |Wallace  |grocery_pos   |104           |10003.130000000001|
# |+t6qVFJfNz                     |Gloria   |Wallace  |gas_transport |135           |8151.8499999999985|
# |+t6qVFJfNz                     |Gloria   |Wallace  |kids_pets     |101           |4913.75           |
# |+t6qVFJfNz                     |Gloria   |Wallace  |misc_net      |53            |4884.14           |
# |+vZtuxJecx                     |Melissa  |Krause   |grocery_pos   |176           |22570.51          |
# |+vZtuxJecx                     |Melissa  |Krause   |gas_transport |314           |18873.989999999998|
# |+vZtuxJecx                     |Melissa  |Krause   |shopping_net  |177           |10249.52          |
# |+vZtuxJecx                     |Melissa  |Krause   |home          |186           |10117.050000000001|
# |+vZtuxJecx                     |Melissa  |Krause   |kids_pets     |199           |9472.279999999999 |
# |/+S02Hy2DR                     |Monica   |Tucker   |gas_transport |304           |18401.610000000004|
# |/+S02Hy2DR                     |Monica   |Tucker   |shopping_pos  |242           |11691.589999999998|
# |/+S02Hy2DR                     |Monica   |Tucker   |kids_pets     |212           |10270.25          |
# |/+S02Hy2DR                     |Monica   |Tucker   |entertainment |219           |10025.599999999999|
# |/+S02Hy2DR                     |Monica   |Tucker   |shopping_net  |201           |10008.650000000001|
# |//EcNNQzHq                     |Elizabeth|Glover   |grocery_pos   |100           |19853.559999999998|
# |//EcNNQzHq                     |Elizabeth|Glover   |shopping_net  |100           |9986.759999999998 |
# |//EcNNQzHq                     |Elizabeth|Glover   |shopping_pos  |105           |9492.51           |
# |//EcNNQzHq                     |Elizabeth|Glover   |home          |110           |7032.62           |
# |//EcNNQzHq                     |Elizabeth|Glover   |entertainment |63            |6276.020000000001 |
# |/5nsfsayET                     |Daniel   |Graham   |grocery_pos   |59            |3540.2700000000004|
# |/5nsfsayET                     |Daniel   |Graham   |gas_transport |49            |3491.84           |
# |/5nsfsayET                     |Daniel   |Graham   |misc_pos      |37            |3139.7699999999995|
# |/5nsfsayET                     |Daniel   |Graham   |home          |52            |2997.3899999999994|
# |/5nsfsayET                     |Daniel   |Graham   |health_fitness|35            |2034.75           |
# |/IchXo9f+U                     |Cody     |Miller   |grocery_pos   |162           |14736.72          |
# |/IchXo9f+U                     |Cody     |Miller   |kids_pets     |152           |11730.210000000001|
# |/IchXo9f+U                     |Cody     |Miller   |food_dining   |137           |10324.279999999999|
# |/IchXo9f+U                     |Cody     |Miller   |gas_transport |146           |10251.560000000001|
# |/IchXo9f+U                     |Cody     |Miller   |home          |142           |8987.34           |
# |/J6jpvYsGQ                     |Michael  |Garner   |grocery_pos   |59            |5311.279999999999 |
# |/J6jpvYsGQ                     |Michael  |Garner   |kids_pets     |48            |3870.47           |
# |/J6jpvYsGQ                     |Michael  |Garner   |shopping_pos  |50            |3693.84           |
# |/J6jpvYsGQ                     |Michael  |Garner   |food_dining   |41            |3304.77           |
# |/J6jpvYsGQ                     |Michael  |Garner   |home          |51            |3265.16           |
# |/J8JeT/v0R                     |Kaitlyn  |Newman   |grocery_pos   |102           |13499.01          |
# |/J8JeT/v0R                     |Kaitlyn  |Newman   |gas_transport |131           |7906.620000000001 |
# |/J8JeT/v0R                     |Kaitlyn  |Newman   |shopping_pos  |77            |6752.959999999999 |
# |/J8JeT/v0R                     |Kaitlyn  |Newman   |home          |111           |5333.6900000000005|
# |/J8JeT/v0R                     |Kaitlyn  |Newman   |misc_net      |78            |4353.930000000001 |
# |/LkXO9OTYb                     |Joseph   |Gonzalez |gas_transport |250           |17263.350000000002|
# |/LkXO9OTYb                     |Joseph   |Gonzalez |grocery_pos   |281           |16689.309999999998|
# |/LkXO9OTYb                     |Joseph   |Gonzalez |shopping_pos  |228           |14704.759999999997|
# |/LkXO9OTYb                     |Joseph   |Gonzalez |home          |244           |14488.130000000001|
# |/LkXO9OTYb                     |Joseph   |Gonzalez |shopping_net  |175           |13885.599999999997|
# |/N4vktR2co                     |Jessica  |Shaw     |grocery_pos   |161           |14608.620000000004|
# |/N4vktR2co                     |Jessica  |Shaw     |kids_pets     |158           |12867.900000000001|
# |/N4vktR2co                     |Jessica  |Shaw     |food_dining   |149           |11062.2           |
# |/N4vktR2co                     |Jessica  |Shaw     |home          |151           |10080.609999999999|
# |/N4vktR2co                     |Jessica  |Shaw     |gas_transport |141           |9636.0            |
# |/RCaX6ccpd                     |Shannon  |Patterson|grocery_pos   |156           |14172.61          |
# |/RCaX6ccpd                     |Shannon  |Patterson|kids_pets     |151           |13270.310000000001|
# |/RCaX6ccpd                     |Shannon  |Patterson|shopping_pos  |180           |10009.949999999999|
# |/RCaX6ccpd                     |Shannon  |Patterson|gas_transport |149           |9964.100000000002 |
# |/RCaX6ccpd                     |Shannon  |Patterson|home          |147           |9217.41           |
# +-------------------------------+---------+---------+--------------+--------------+------------------+
# only showing top 100 rows
